# %%
import pandas as pd

# %%
from pandas import read_csv, DataFrame, Series

# %%
data=read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data.pivot_table('PassengerId', 'Pclass', 'Survived', 'count').plot(kind='bar',stacked=True)

# %%
import matplotlib.pyplot as plt

# %%
fig, axes=plt.subplots(ncols=2)
data.pivot_table('PassengerId', ['Parch'], 'Survived', 'count').plot(ax=axes[0], title='SibSp')
data.pivot_table('PassengerId',['Parch'], 'Survived', 'count').plot(ax=axes[1], title='Parch')

# %%
data.PassengerId[data.Cabin.notnull()].count()
# Out:
# 204

# %%
data.PassengerId[data.Age.notnull()].count()
# Out:
# 714

# %%
data.Age=data.Age.median()

# %%
data[data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  28.0      0      0  113572  80.0   B28      NaN
# 829  female  28.0      0      0  113572  80.0   B28      NaN

# %%
data.PassengerId[data.Fare.isnull()]
# Out:
# Series([], Name: PassengerId, dtype: int64)

# %%
data=data.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  28.0      1      0    7.2500        S
# 1           1       1  female  28.0      1      0   71.2833        C
# 2           1       3  female  28.0      0      0    7.9250        S
# 3           1       1  female  28.0      1      0   53.1000        S
# 4           0       3    male  28.0      0      0    8.0500        S
# 5           0       3    male  28.0      0      0    8.4583        Q
# 6           0       1    male  28.0      0      0   51.8625        S
# 7           0       3    male  28.0      3      1   21.0750        S
# 8           1       3  female  28.0      0      2   11.1333        S
# 9           1       2  female  28.0      1      0   30.0708        C
# 10          1       3  female  28.0      1      1   16.7000        S
# 11          1       1  female  28.0      0      0   26.5500        S
# 12          0       3    male  28.0      0      0    8.0500        S
# ...

# %%
print(data.head())
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  28.0      1      0   7.2500        S
# 1         1       1  female  28.0      1      0  71.2833        C
# 2         1       3  female  28.0      0      0   7.9250        S
# 3         1       1  female  28.0      1      0  53.1000        S
# 4         0       3    male  28.0      0      0   8.0500        S

# %%
titanic=read_csv('train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
print(titanic.groupby(['Sex','Survived'])['PassengerId'].count())
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
print(titanic.groupby(['Sex','Pclass'])['PassengerId'].count())
# Out:
# Sex     Pclass
# female  1          94
#         2          76
#         3         144
# male    1         122
#         2         108
#         3         347
# Name: PassengerId, dtype: int64

# %%
titanic.groupby([titanic.Pclass==1,titanic.Sex=='Male'])['PassengerId'].count()
# Out:
# Pclass  Sex
# False   False    675
# True    False    216
# Name: PassengerId, dtype: int64

# %%
titanic[titanic.Age<18].groupby(['Pclass'])['PassengerId'].count()
# Out:
# Pclass
# 1    12
# 2    23
# 3    78
# Name: PassengerId, dtype: int64

# %%
titanic.PassengerId[titanic.Parch.isnull()].count()
# Out:
# 0

# %%
titanic[titanic.Fare>titanic.Fare.median()].groupby([titanic.Embarked=='Q'])['PassengerId'].count()
# Out:
# Embarked
# False    424
# True      20
# Name: PassengerId, dtype: int64

# %%
# Out:
# Sex
# False    28.0
# Name: Age, dtype: float64

# %%
titanic.PassengerId[titanic.Age>60].count()
# Out:
# 22

# %%
print(titanic.groupby(['Embarked'])['Fare'].median())
# Out:
# Embarked
# C    29.70
# Q     7.75
# S    13.00
# Name: Fare, dtype: float64

# %%
print(titanic.groupby(['Pclass'])['Fare'].median())
# Out:
# Pclass
# 1    60.2875
# 2    14.2500
# 3     8.0500
# Name: Fare, dtype: float64

# %%
titanic.pivot_table(titanic[titanic.Age<18], 'Pclass', 'Age', 'count').plot(kind='bar',stacked=True)
